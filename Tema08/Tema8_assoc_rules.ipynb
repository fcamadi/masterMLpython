# %% [markdown]
# # Tema 8: Ejercicio Reglas de Asociación
#
# BÚSQUEDA DE PATRONES MEDIANTE REGLAS DE ASOCIACIÓN
#
# Utilizando el dataset **IncomeESL** incluido con la librería arules (R), se pide generar
# reglas de asociación.
#
# Para ello, previamente deberá depurar el dataset. En particular:
# -Revisar que no haya valores omitidos.
# -Transformar los factores en valores numéricos. ← no es necesario!!!
# -Una vez depurado el dataset, crear la matriz de transacciones usando la
# función transactions.
#
# A la hora de ejecutar el algoritmo para obtener las reglas, no olvide establecer
# los valores de los parámetros de la función apriori, justificando el motivo de su elección.
#
# Por último, elabore un breve informe resumiendo las reglas obtenidas y
# analizando su significado.

# %% [markdown]
# Importamos dependencias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## Paso 1: importar datos

# %%
## import data
income_raw = pd.read_csv(r"./income_raw.csv",sep=',')

# %%
income_raw.head()
# Out:
#    Unnamed  income     sex marital status    age            education  \
# 0        1     75+  female        married  45-54  college (1-3 years)
# 1        2     75+    male        married  45-54     college graduate
# 2        3     75+  female        married  25-34     college graduate
# 3        4  [0,10)  female         single  14-17          grades 9-11
# 4        5  [0,10)  female         single  14-17          grades 9-11
#
#                 occupation years in bay area dual incomes number in household  \
# 0                homemaker               >10           no                   3
# 1                homemaker               >10           no                   5
# 2  professional/managerial               >10          yes                   3
# 3                  student               >10  not married                   4
# 4                  student               4-6  not married                   4
#
#   number of children        householder status type of home  \
# 0                  0                       own        house
# 1                  2                       own        house
# 2                  1                      rent    apartment
# 3                  2  live with parents/family        house
# 4                  2  live with parents/family        house
#
#   ethnic classification language in home
# 0                 white              NaN
# 1                 white          english
# 2                 white          english
# 3                 white          english
# 4                 white          english

# %%
income_raw.describe(include='all')
# Out:
#             Unnamed  income     sex marital status    age  \
# count   8993.000000    8993    8993           8833   8993
# unique          NaN       9       2              5      7
# top             NaN  [0,10)  female         single  25-34
# freq            NaN    1745    4918           3654   2249
# mean    4497.000000     NaN     NaN            NaN    NaN
# std     2596.199819     NaN     NaN            NaN    NaN
# min        1.000000     NaN     NaN            NaN    NaN
# 25%     2249.000000     NaN     NaN            NaN    NaN
# 50%     4497.000000     NaN     NaN            NaN    NaN
# 75%     6745.000000     NaN     NaN            NaN    NaN
# max     8993.000000     NaN     NaN            NaN    NaN
#
#                   education               occupation years in bay area  \
# count                  8907                     8857              8080
# unique                    6                        9                 5
# top     college (1-3 years)  professional/managerial               >10
# freq                   3066                     2820              5182
# mean                    NaN                      NaN               NaN
# std                     NaN                      NaN               NaN
# min                     NaN                      NaN               NaN
# 25%                     NaN                      NaN               NaN
# 50%                     NaN                      NaN               NaN
# 75%                     NaN                      NaN               NaN
# max                     NaN                      NaN               NaN
#
#        dual incomes number in household number of children householder status  \
# count          8993                8618               8993               8753
# unique            3                   9                 10                  3
# top     not married                   2                  0               rent
# freq           5438                2664               5724               3670
# mean            NaN                 NaN                NaN                NaN
# std             NaN                 NaN                NaN                NaN
# min             NaN                 NaN                NaN                NaN
# 25%             NaN                 NaN                NaN                NaN
# 50%             NaN                 NaN                NaN                NaN
# 75%             NaN                 NaN                NaN                NaN
# max             NaN                 NaN                NaN                NaN
#
#        type of home ethnic classification language in home
# count          8636                  8925             8634
# unique            5                     8                3
# top           house                 white          english
# freq           5073                  5811             7794
# mean            NaN                   NaN              NaN
# std             NaN                   NaN              NaN
# min             NaN                   NaN              NaN
# 25%             NaN                   NaN              NaN
# 50%             NaN                   NaN              NaN
# 75%             NaN                   NaN              NaN
# max             NaN                   NaN              NaN

# %% [markdown]
# ## Paso 2: explorar y procesar datos

# %% [markdown]
# Tenemos que eliminar los registros que no estén completos.

# %%
#rename first column
#income_raw.rename(columns={'Unnamed':'id'}, inplace=True)
#income_raw.head()

#remove first column
income_raw.drop(income_raw.columns[0], axis=1, inplace=True)
income_raw.head()
# Out:
#    income     sex marital status    age            education  \
# 0     75+  female        married  45-54  college (1-3 years)
# 1     75+    male        married  45-54     college graduate
# 2     75+  female        married  25-34     college graduate
# 3  [0,10)  female         single  14-17          grades 9-11
# 4  [0,10)  female         single  14-17          grades 9-11
#
#                 occupation years in bay area dual incomes number in household  \
# 0                homemaker               >10           no                   3
# 1                homemaker               >10           no                   5
# 2  professional/managerial               >10          yes                   3
# 3                  student               >10  not married                   4
# 4                  student               4-6  not married                   4
#
#   number of children        householder status type of home  \
# 0                  0                       own        house
# 1                  2                       own        house
# 2                  1                      rent    apartment
# 3                  2  live with parents/family        house
# 4                  2  live with parents/family        house
#
#   ethnic classification language in home
# 0                 white              NaN
# 1                 white          english
# 2                 white          english
# 3                 white          english
# 4                 white          english

# %%
#remove no complete records
income_complete = income_raw.dropna(axis=0, inplace=False)

# %%
income_complete.describe(include='all')
# Out:
#         income     sex marital status    age            education  \
# count     6876    6876           6876   6876                 6876
# unique       9       2              5      7                    6
# top     [0,10)  female         single  25-34  college (1-3 years)
# freq      1255    3809           2813   1768                 2407
#
#                      occupation years in bay area dual incomes  \
# count                      6876              6876         6876
# unique                        9                 5            3
# top     professional/managerial               >10  not married
# freq                       2333              4446         4114
#
#        number in household number of children householder status type of home  \
# count                 6876               6876               6876         6876
# unique                   9                 10                  3            5
# top                      2                  0               rent        house
# freq                  2156               4276               2882         4102
#
#        ethnic classification language in home
# count                   6876             6876
# unique                     8                3
# top                    white          english
# freq                    4605             6277

# %%
income_complete.head()
# Out:
#     income     sex marital status    age            education  \
# 1      75+    male        married  45-54     college graduate
# 2      75+  female        married  25-34     college graduate
# 3   [0,10)  female         single  14-17          grades 9-11
# 4   [0,10)  female         single  14-17          grades 9-11
# 5  [50,75)    male        married  55-64  college (1-3 years)
#
#                 occupation years in bay area dual incomes number in household  \
# 1                homemaker               >10           no                   5
# 2  professional/managerial               >10          yes                   3
# 3                  student               >10  not married                   4
# 4                  student               4-6  not married                   4
# 5                  retired               >10           no                   2
#
#   number of children        householder status type of home  \
# 1                  2                       own        house
# 2                  1                      rent    apartment
# 3                  2  live with parents/family        house
# 4                  2  live with parents/family        house
# 5                  0                       own        house
#
#   ethnic classification language in home
# 1                 white          english
# 2                 white          english
# 3                 white          english
# 4                 white          english
# 5                 white          english

# %%
# Total number of transactions and ítems
#for item in income_complete:
#    print(f"Total items {item}: {income_complete[item].nunique()}")

# %%
#income_complete.groupby('id')['income'].apply(list)
#income_complete.groupby('id')['sex'].apply(list)

# %%
income_hot_encoded = pd.get_dummies(income_complete, dtype='boolean')  

# if we do hot encoding with integers we get the warning:
#
# /home/francd/anaconda3/envs/masterMLpythonConda/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: 
# DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type

income_hot_encoded.head()
# Out:
#    income_75+  income_[0,10)  income_[10,15)  income_[15,20)  income_[20,25)  \
# 1        True          False           False           False           False
# 2        True          False           False           False           False
# 3       False           True           False           False           False
# 4       False           True           False           False           False
# 5       False          False           False           False           False
#
#    income_[25,30)  income_[30,40)  income_[40,50)  income_[50,75)  sex_female  \
# 1           False           False           False           False       False
# 2           False           False           False           False        True
# 3           False           False           False           False        True
# 4           False           False           False           False        True
# 5           False           False           False            True       False
#
#    ...  ethnic classification_asian  ethnic classification_black  \
# 1  ...                        False                        False
# 2  ...                        False                        False
# 3  ...                        False                        False
# 4  ...                        False                        False
# 5  ...                        False                        False
#
#    ethnic classification_east indian  ethnic classification_hispanic  \
# 1                              False                           False
# 2                              False                           False
# 3                              False                           False
# 4                              False                           False
# 5                              False                           False
#
#    ethnic classification_other  ethnic classification_pacific islander  \
# 1                        False                                   False
# 2                        False                                   False
# 3                        False                                   False
# 4                        False                                   False
# 5                        False                                   False
#
#    ethnic classification_white  language in home_english  \
# 1                         True                      True
# 2                         True                      True
# 3                         True                      True
# 4                         True                      True
# 5                         True                      True
#
#    language in home_other  language in home_spanish
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
# 5                   False                     False
#
# [5 rows x 84 columns]

# %% [markdown]
# ## Paso 3: Entrenamiento del modelo

# %%
# Apply the apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(income_hot_encoded, min_support=0.5, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.553956                                       (sex_female)
# 1   0.646597                            (years in bay area_>10)
# 2   0.598313                         (dual incomes_not married)
# 3   0.621873                             (number of children_0)
# 4   0.596568                               (type of home_house)
# 5   0.669721                      (ethnic classification_white)
# 6   0.912885                         (language in home_english)
# 7   0.512216             (language in home_english, sex_female)
# 8   0.601367  (years in bay area_>10, language in home_english)
# 9   0.542612  (dual incomes_not married, language in home_en...
# 10  0.580134   (language in home_english, number of children_0)
# 11  0.544648     (type of home_house, language in home_english)
# 12   0.65954  (ethnic classification_white, language in home...

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
rules
# Out:
#                       antecedents                    consequents  \
# 0      (language in home_english)                   (sex_female)
# 1                    (sex_female)     (language in home_english)
# 2         (years in bay area_>10)     (language in home_english)
# 3      (language in home_english)        (years in bay area_>10)
# 4      (dual incomes_not married)     (language in home_english)
# 5      (language in home_english)     (dual incomes_not married)
# 6      (language in home_english)         (number of children_0)
# 7          (number of children_0)     (language in home_english)
# 8            (type of home_house)     (language in home_english)
# 9      (language in home_english)           (type of home_house)
# 10  (ethnic classification_white)     (language in home_english)
# 11     (language in home_english)  (ethnic classification_white)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.912885            0.553956  0.512216    0.561096  1.012890
# 1             0.553956            0.912885  0.512216    0.924652  1.012890
# 2             0.646597            0.912885  0.601367    0.930049  1.018802
# 3             0.912885            0.646597  0.601367    0.658754  1.018802
# 4             0.598313            0.912885  0.542612    0.906903  0.993447
# 5             0.912885            0.598313  0.542612    0.594392  0.993447
# 6             0.912885            0.621873  0.580134    0.635495  1.021904
# 7             0.621873            0.912885  0.580134    0.932881  1.021904
# 8             0.596568            0.912885  0.544648    0.912969  1.000092
# 9             0.912885            0.596568  0.544648    0.596623  1.000092
# 10            0.669721            0.912885  0.659540    0.984799  1.078776
# 11            0.912885            0.669721  0.659540    0.722479  1.078776
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0  0.006518    1.016268       0.146079  0.536563
# 1                1.0  0.006518    1.156166       0.028530  0.536563
# 2                1.0  0.011098    1.245375       0.052221  0.627656
# 3                1.0  0.011098    1.035626       0.211848  0.627656
# 4                1.0 -0.003579    0.935743      -0.016156  0.560210
# 5                1.0 -0.003579    0.990334      -0.070389  0.560210
# 6                1.0  0.012435    1.037370       0.246049  0.607709
# 7                1.0  0.012435    1.297917       0.056686  0.607709
# 8                1.0  0.000050    1.000964       0.000228  0.564516
# 9                1.0  0.000050    1.000136       0.001055  0.564516
# 10               1.0  0.048162    5.730896       0.221097  0.714511
# 11               1.0  0.048162    1.190105       0.838249  0.714511
#
#     certainty  kulczynski
# 0    0.016008    0.742874
# 1    0.135072    0.742874
# 2    0.197029    0.794402
# 3    0.034401    0.794402
# 4   -0.068670    0.750648
# 5   -0.009761    0.750648
# 6    0.036024    0.784188
# 7    0.229534    0.784188
# 8    0.000963    0.754796
# 9    0.000136    0.754796
# 10   0.825507    0.853639
# 11   0.159738    0.853639

# %% [markdown]
# Igual que en R. Las reglas son las mismas que en R para soporte=0.5 y confianza=0.5 ...

# %% [markdown]
# **Antes de seguir, vamos a hacer lo mismo que en R: tranformar la variable "income" de 9 factores en 3:**

# %%
pd.Categorical(income_complete['income'])
# Out:
# ['75+', '75+', '[0,10)', '[0,10)', '[50,75)', ..., '[0,10)', '[10,15)', '[0,10)', '[20,25)', '[30,40)']
# Length: 6876
# Categories (9, object): ['75+', '[0,10)', '[10,15)', '[15,20)', ..., '[25,30)', '[30,40)', '[40,50)', '[50,75)']

# %%
def incomeTo3Levels(level):
    match level:
        case "[0,10)" | "[10,15)" | "[15,20)": 
            return "0-20k$"
        case "[20,25)" | "[25,30)" | "[30,40)" | "[40,50)": 
            return "20k-50k$"
        case "[50,75)" | "75+": 
            return "50k+$"
#tests
#print(incomeTo3Levels("[10,15)"))
#print(incomeTo3Levels("[30,40)"))
#print(incomeTo3Levels("75+"))

# %%
levels3L_df = income_complete['income'].apply(lambda income: incomeTo3Levels(income)).rename("income3L")
levels3L_df.head()
# Out:
# 1     50k+$
# 2     50k+$
# 3    0-20k$
# 4    0-20k$
# 5     50k+$
# Name: income3L, dtype: object

# %%
income_complete = income_complete.join(levels3L_df)
income_complete
# Out:
#        income     sex marital status    age            education  \
# 1         75+    male        married  45-54     college graduate
# 2         75+  female        married  25-34     college graduate
# 3      [0,10)  female         single  14-17          grades 9-11
# 4      [0,10)  female         single  14-17          grades 9-11
# 5     [50,75)    male        married  55-64  college (1-3 years)
# ...       ...     ...            ...    ...                  ...
# 8988   [0,10)  female         single  14-17             grade <9
# 8989  [10,15)    male         single  18-24  college (1-3 years)
# 8990   [0,10)  female         single  14-17          grades 9-11
# 8991  [20,25)    male        married  55-64  college (1-3 years)
# 8992  [30,40)    male         single  25-34  college (1-3 years)
#
#                    occupation years in bay area dual incomes  \
# 1                   homemaker               >10           no
# 2     professional/managerial               >10          yes
# 3                     student               >10  not married
# 4                     student               4-6  not married
# 5                     retired               >10           no
# ...                       ...               ...          ...
# 8988                    sales               >10  not married
# 8989  professional/managerial               >10  not married
# 8990  professional/managerial               >10  not married
# 8991                  laborer               >10          yes
# 8992  professional/managerial               >10  not married
#
#      number in household number of children        householder status  \
# 1                      5                  2                       own
# 2                      3                  1                      rent
# 3                      4                  2  live with parents/family
# 4                      4                  2  live with parents/family
# 5                      2                  0                       own
# ...                  ...                ...                       ...
# 8988                   3                  2  live with parents/family
# 8989                   4                  0  live with parents/family
# 8990                   3                  2  live with parents/family
# 8991                   3                  1                      rent
# 8992                   1                  0                      rent
#
#      type of home ethnic classification language in home  income3L
# 1           house                 white          english     50k+$
# 2       apartment                 white          english     50k+$
# 3           house                 white          english    0-20k$
# 4           house                 white          english    0-20k$
# 5           house                 white          english     50k+$
# ...           ...                   ...              ...       ...
# 8988        house                 white          english    0-20k$
# 8989        house                 white          english    0-20k$
# 8990        house                 white          english    0-20k$
# 8991    apartment                 white          english  20k-50k$
# 8992    apartment              hispanic          english  20k-50k$
#
# [6876 rows x 15 columns]

# %%
income3L = income_complete.drop('income',axis=1).copy()
income3L
# Out:
#          sex marital status    age            education  \
# 1       male        married  45-54     college graduate
# 2     female        married  25-34     college graduate
# 3     female         single  14-17          grades 9-11
# 4     female         single  14-17          grades 9-11
# 5       male        married  55-64  college (1-3 years)
# ...      ...            ...    ...                  ...
# 8988  female         single  14-17             grade <9
# 8989    male         single  18-24  college (1-3 years)
# 8990  female         single  14-17          grades 9-11
# 8991    male        married  55-64  college (1-3 years)
# 8992    male         single  25-34  college (1-3 years)
#
#                    occupation years in bay area dual incomes  \
# 1                   homemaker               >10           no
# 2     professional/managerial               >10          yes
# 3                     student               >10  not married
# 4                     student               4-6  not married
# 5                     retired               >10           no
# ...                       ...               ...          ...
# 8988                    sales               >10  not married
# 8989  professional/managerial               >10  not married
# 8990  professional/managerial               >10  not married
# 8991                  laborer               >10          yes
# 8992  professional/managerial               >10  not married
#
#      number in household number of children        householder status  \
# 1                      5                  2                       own
# 2                      3                  1                      rent
# 3                      4                  2  live with parents/family
# 4                      4                  2  live with parents/family
# 5                      2                  0                       own
# ...                  ...                ...                       ...
# 8988                   3                  2  live with parents/family
# 8989                   4                  0  live with parents/family
# 8990                   3                  2  live with parents/family
# 8991                   3                  1                      rent
# 8992                   1                  0                      rent
#
#      type of home ethnic classification language in home  income3L
# 1           house                 white          english     50k+$
# 2       apartment                 white          english     50k+$
# 3           house                 white          english    0-20k$
# 4           house                 white          english    0-20k$
# 5           house                 white          english     50k+$
# ...           ...                   ...              ...       ...
# 8988        house                 white          english    0-20k$
# 8989        house                 white          english    0-20k$
# 8990        house                 white          english    0-20k$
# 8991    apartment                 white          english  20k-50k$
# 8992    apartment              hispanic          english  20k-50k$
#
# [6876 rows x 14 columns]

# %% [markdown]
# Volvemos a repetir los pasos (crear la matriz dispersa mediante hot encoding, etc.)

# %%
income3L_hot_encoded = pd.get_dummies(income3L, dtype='boolean')  

income3L_hot_encoded.head()

#other way
#
#te = TransactionEncoder()
#transactions = te.fit(dataset).transform(dataset, sparse=True)
#sparse_df = pd.DataFrame.sparse.from_spmatrix(transactions, columns=te.columns_)
#sparse_df
# Out:
#    sex_female  sex_male  marital status_cohabitation  marital status_divorced  \
# 1       False      True                        False                    False
# 2        True     False                        False                    False
# 3        True     False                        False                    False
# 4        True     False                        False                    False
# 5       False      True                        False                    False
#
#    marital status_married  marital status_single  marital status_widowed  \
# 1                    True                  False                   False
# 2                    True                  False                   False
# 3                   False                   True                   False
# 4                   False                   True                   False
# 5                    True                  False                   False
#
#    age_14-17  age_18-24  age_25-34  ...  ethnic classification_hispanic  \
# 1      False      False      False  ...                           False
# 2      False      False       True  ...                           False
# 3       True      False      False  ...                           False
# 4       True      False      False  ...                           False
# 5      False      False      False  ...                           False
#
#    ethnic classification_other  ethnic classification_pacific islander  \
# 1                        False                                   False
# 2                        False                                   False
# 3                        False                                   False
# 4                        False                                   False
# 5                        False                                   False
#
#    ethnic classification_white  language in home_english  \
# 1                         True                      True
# 2                         True                      True
# 3                         True                      True
# 4                         True                      True
# 5                         True                      True
#
#    language in home_other  language in home_spanish  income3L_0-20k$  \
# 1                   False                     False            False
# 2                   False                     False            False
# 3                   False                     False             True
# 4                   False                     False             True
# 5                   False                     False            False
#
#    income3L_20k-50k$  income3L_50k+$
# 1              False            True
# 2              False            True
# 3              False           False
# 4              False           False
# 5              False            True
#
# [5 rows x 78 columns]

# %% [markdown]
# Aplicar Apriori:

# %%
# Apply the apriori algorithm to find frequent itemsets
frequent_itemsets_3L = apriori(income3L_hot_encoded, min_support=0.1, use_colnames=True)
#frequent_itemsets_3L

# %%
# Generate association rules
rules3L = association_rules(frequent_itemsets_3L, metric="confidence", min_threshold=0.55)
rules3L
# Out:
#                                             antecedents  \
# 0                              (marital status_married)
# 1                                           (age_35-44)
# 2                       (education_college (1-3 years))
# 3                      (education_high school graduate)
# 4                               (years in bay area_>10)
# ...                                                 ...
# 5515  (type of home_apartment, language in home_engl...
# 5516  (householder status_rent, type of home_apartme...
# 5517  (type of home_apartment, ethnic classification...
# 5518  (dual incomes_not married, type of home_apartm...
# 5519  (type of home_apartment, ethnic classification...
#
#                                             consequents  antecedent support  \
# 0                                          (sex_female)            0.385689
# 1                                          (sex_female)            0.184264
# 2                                          (sex_female)            0.350058
# 3                                          (sex_female)            0.215096
# 4                                          (sex_female)            0.646597
# ...                                                 ...                 ...
# 5515  (householder status_rent, dual incomes_not mar...            0.197935
# 5516  (dual incomes_not married, language in home_en...            0.164921
# 5517  (householder status_rent, dual incomes_not mar...            0.169721
# 5518  (householder status_rent, ethnic classificatio...            0.206079
# 5519  (householder status_rent, dual incomes_not mar...            0.173211
#
#       consequent support   support  confidence      lift  representativity  \
# 0               0.553956  0.231094    0.599170  1.081621               1.0
# 1               0.553956  0.102676    0.557222  1.005896               1.0
# 2               0.553956  0.195462    0.558371  1.007971               1.0
# 3               0.553956  0.125800    0.584855  1.055779               1.0
# 4               0.553956  0.370273    0.572650  1.033746               1.0
# ...                  ...       ...         ...       ...               ...
# 5515            0.196335  0.114020    0.576047  2.934000               1.0
# 5516            0.368237  0.114020    0.691358  1.877479               1.0
# 5517            0.242001  0.114020    0.671808  2.776053               1.0
# 5518            0.218732  0.114020    0.553282  2.529497               1.0
# 5519            0.227749  0.114020    0.658270  2.890337               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.017439    1.112803       0.122840  0.326149   0.101368    0.508170
# 1     0.000602    1.007376       0.007185  0.161556   0.007322    0.371286
# 2     0.001546    1.009999       0.012167  0.275862   0.009900    0.455610
# 3     0.006646    1.074429       0.067310  0.195569   0.069273    0.405974
# 4     0.012087    1.043743       0.092371  0.445963   0.041910    0.620533
# ...        ...         ...            ...       ...        ...         ...
# 5515  0.075158    1.895646       0.821839  0.406850   0.472475    0.578394
# 5516  0.053290    2.046911       0.559673  0.272033   0.511459    0.500497
# 5517  0.072947    2.309620       0.770556  0.383000   0.567028    0.571481
# 5518  0.068944    1.748905       0.761618  0.366869   0.428214    0.537279
# 5519  0.074571    2.259831       0.791036  0.397364   0.557489    0.579454
#
# [5520 rows x 14 columns]

# %%
#look for income in RHS/consequents
#match = {"income3L_0-20k$", "income3L_20k-50k$", "income3L_50k+$"}  
match = {"income3L_20k-50k$"}  

rules3L['3levels'] = ~rules3L['consequents'].apply(match.isdisjoint) 
#rules3L

# %%
rules3L_filtered = rules3L.loc[rules3L['3levels']==True]
rules3L_filtered
# Out:
#                                             antecedents          consequents  \
# 759                (householder status_rent, age_25-34)  (income3L_20k-50k$)
# 861   (dual incomes_not married, occupation_professi...  (income3L_20k-50k$)
# 1890  (householder status_rent, language in home_eng...  (income3L_20k-50k$)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 759             0.172048            0.403578  0.100931    0.586644  1.453609
# 861             0.170448            0.403578  0.101658    0.596416  1.477823
# 1890            0.184264            0.403578  0.101803    0.552486  1.368971
#
#       representativity  leverage  conviction  zhangs_metric   jaccard  \
# 759                1.0  0.031496    1.442879       0.376902  0.212623
# 861                1.0  0.032869    1.477816       0.389763  0.215209
# 1890               1.0  0.027438    1.332746       0.330406  0.209455
#
#       certainty  kulczynski  3levels
# 759    0.306941    0.418367     True
# 861    0.323326    0.424154     True
# 1890   0.249670    0.402369     True

# %% [markdown]
# Son las mismas 3 reglas relacionadas con los sueldos intermedios que en R !!!
