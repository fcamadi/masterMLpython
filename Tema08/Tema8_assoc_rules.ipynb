# %% [markdown]
# # Tema 8: Ejercicio Reglas de Asosciación
#
# BÚSQUEDA DE PATRONES MEDIANTE REGLAS DE ASOCIACIÓN
#
# Utilizando el dataset **IncomeESL** incluido con la librería arules (R), se pide generar
# reglas de asociación.
#
# Para ello, previamente deberá depurar el dataset. En particular:
# -Revisar que no haya valores omitidos.
# -Transformar los factores en valores numéricos. ← no es necesario!!!
# -Una vez depurado el dataset, crear la matriz de transacciones usando la
# función transactions.
#
# A la hora de ejecutar el algoritmo para obtener las reglas, no olvide establecer
# los valores de los parámetros de la función apriori, justificando el motivo de su elección.
#
# Por último, elabore un breve informe resumiendo las reglas obtenidas y
# analizando su significado.

# %% [markdown]
# Importamos dependencias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Paso 1: importar datos

# %%
## import data
income_raw = pd.read_csv(r"./income_raw.csv",sep=',')

# %%
income_raw
# Out:
#       Unnamed   income     sex marital status    age            education  \
# 0           1      75+  female        married  45-54  college (1-3 years)
# 1           2      75+    male        married  45-54     college graduate
# 2           3      75+  female        married  25-34     college graduate
# 3           4   [0,10)  female         single  14-17          grades 9-11
# 4           5   [0,10)  female         single  14-17          grades 9-11
# ...       ...      ...     ...            ...    ...                  ...
# 8988     8989   [0,10)  female         single  14-17             grade <9
# 8989     8990  [10,15)    male         single  18-24  college (1-3 years)
# 8990     8991   [0,10)  female         single  14-17          grades 9-11
# 8991     8992  [20,25)    male        married  55-64  college (1-3 years)
# 8992     8993  [30,40)    male         single  25-34  college (1-3 years)
#
#                    occupation years in bay area dual incomes  \
# 0                   homemaker               >10           no
# 1                   homemaker               >10           no
# 2     professional/managerial               >10          yes
# 3                     student               >10  not married
# 4                     student               4-6  not married
# ...                       ...               ...          ...
# 8988                    sales               >10  not married
# 8989  professional/managerial               >10  not married
# 8990  professional/managerial               >10  not married
# 8991                  laborer               >10          yes
# 8992  professional/managerial               >10  not married
#
#      number in household number of children        householder status  \
# 0                      3                  0                       own
# 1                      5                  2                       own
# 2                      3                  1                      rent
# 3                      4                  2  live with parents/family
# 4                      4                  2  live with parents/family
# ...                  ...                ...                       ...
# 8988                   3                  2  live with parents/family
# 8989                   4                  0  live with parents/family
# 8990                   3                  2  live with parents/family
# 8991                   3                  1                      rent
# 8992                   1                  0                      rent
#
#      type of home ethnic classification language in home
# 0           house                 white              NaN
# 1           house                 white          english
# 2       apartment                 white          english
# 3           house                 white          english
# 4           house                 white          english
# ...           ...                   ...              ...
# 8988        house                 white          english
# 8989        house                 white          english
# 8990        house                 white          english
# 8991    apartment                 white          english
# 8992    apartment              hispanic          english
#
# [8993 rows x 15 columns]

# %%
income_raw.describe(include='all')
# Out:
#             Unnamed  income     sex marital status    age  \
# count   8993.000000    8993    8993           8833   8993
# unique          NaN       9       2              5      7
# top             NaN  [0,10)  female         single  25-34
# freq            NaN    1745    4918           3654   2249
# mean    4497.000000     NaN     NaN            NaN    NaN
# std     2596.199819     NaN     NaN            NaN    NaN
# min        1.000000     NaN     NaN            NaN    NaN
# 25%     2249.000000     NaN     NaN            NaN    NaN
# 50%     4497.000000     NaN     NaN            NaN    NaN
# 75%     6745.000000     NaN     NaN            NaN    NaN
# max     8993.000000     NaN     NaN            NaN    NaN
#
#                   education               occupation years in bay area  \
# count                  8907                     8857              8080
# unique                    6                        9                 5
# top     college (1-3 years)  professional/managerial               >10
# freq                   3066                     2820              5182
# mean                    NaN                      NaN               NaN
# std                     NaN                      NaN               NaN
# min                     NaN                      NaN               NaN
# 25%                     NaN                      NaN               NaN
# 50%                     NaN                      NaN               NaN
# 75%                     NaN                      NaN               NaN
# max                     NaN                      NaN               NaN
#
#        dual incomes number in household number of children householder status  \
# count          8993                8618               8993               8753
# unique            3                   9                 10                  3
# top     not married                   2                  0               rent
# freq           5438                2664               5724               3670
# mean            NaN                 NaN                NaN                NaN
# std             NaN                 NaN                NaN                NaN
# min             NaN                 NaN                NaN                NaN
# 25%             NaN                 NaN                NaN                NaN
# 50%             NaN                 NaN                NaN                NaN
# 75%             NaN                 NaN                NaN                NaN
# max             NaN                 NaN                NaN                NaN
#
#        type of home ethnic classification language in home
# count          8636                  8925             8634
# unique            5                     8                3
# top           house                 white          english
# freq           5073                  5811             7794
# mean            NaN                   NaN              NaN
# std             NaN                   NaN              NaN
# min             NaN                   NaN              NaN
# 25%             NaN                   NaN              NaN
# 50%             NaN                   NaN              NaN
# 75%             NaN                   NaN              NaN
# max             NaN                   NaN              NaN

# %% [markdown]
# ## Paso 2: explorar y procesar datos

# %% [markdown]
# Tenemos que eliminar los registros que no estén completos.

# %%
#remove first column
#income_raw.drop('Unnamed', axis=1, inplace=True)
#income_raw.head()

# %%
#rename first column
income_raw.rename(columns={'Unnamed':'id'}, inplace=True)
income_raw.head()
# Out:
#    id  income     sex marital status    age            education  \
# 0   1     75+  female        married  45-54  college (1-3 years)
# 1   2     75+    male        married  45-54     college graduate
# 2   3     75+  female        married  25-34     college graduate
# 3   4  [0,10)  female         single  14-17          grades 9-11
# 4   5  [0,10)  female         single  14-17          grades 9-11
#
#                 occupation years in bay area dual incomes number in household  \
# 0                homemaker               >10           no                   3
# 1                homemaker               >10           no                   5
# 2  professional/managerial               >10          yes                   3
# 3                  student               >10  not married                   4
# 4                  student               4-6  not married                   4
#
#   number of children        householder status type of home  \
# 0                  0                       own        house
# 1                  2                       own        house
# 2                  1                      rent    apartment
# 3                  2  live with parents/family        house
# 4                  2  live with parents/family        house
#
#   ethnic classification language in home
# 0                 white              NaN
# 1                 white          english
# 2                 white          english
# 3                 white          english
# 4                 white          english

# %%
#remove now no complete records
income_complete = income_raw.dropna(axis=0, inplace=False)

# %%
income_complete.describe(include='all')
# Out:
#                  id  income     sex marital status    age  \
# count   6876.000000    6876    6876           6876   6876
# unique          NaN       9       2              5      7
# top             NaN  [0,10)  female         single  25-34
# freq            NaN    1255    3809           2813   1768
# mean    4515.674666     NaN     NaN            NaN    NaN
# std     2570.738596     NaN     NaN            NaN    NaN
# min        2.000000     NaN     NaN            NaN    NaN
# 25%     2350.750000     NaN     NaN            NaN    NaN
# 50%     4593.500000     NaN     NaN            NaN    NaN
# 75%     6683.250000     NaN     NaN            NaN    NaN
# max     8993.000000     NaN     NaN            NaN    NaN
#
#                   education               occupation years in bay area  \
# count                  6876                     6876              6876
# unique                    6                        9                 5
# top     college (1-3 years)  professional/managerial               >10
# freq                   2407                     2333              4446
# mean                    NaN                      NaN               NaN
# std                     NaN                      NaN               NaN
# min                     NaN                      NaN               NaN
# 25%                     NaN                      NaN               NaN
# 50%                     NaN                      NaN               NaN
# 75%                     NaN                      NaN               NaN
# max                     NaN                      NaN               NaN
#
#        dual incomes number in household number of children householder status  \
# count          6876                6876               6876               6876
# unique            3                   9                 10                  3
# top     not married                   2                  0               rent
# freq           4114                2156               4276               2882
# mean            NaN                 NaN                NaN                NaN
# std             NaN                 NaN                NaN                NaN
# min             NaN                 NaN                NaN                NaN
# 25%             NaN                 NaN                NaN                NaN
# 50%             NaN                 NaN                NaN                NaN
# 75%             NaN                 NaN                NaN                NaN
# max             NaN                 NaN                NaN                NaN
#
#        type of home ethnic classification language in home
# count          6876                  6876             6876
# unique            5                     8                3
# top           house                 white          english
# freq           4102                  4605             6277
# mean            NaN                   NaN              NaN
# std             NaN                   NaN              NaN
# min             NaN                   NaN              NaN
# 25%             NaN                   NaN              NaN
# 50%             NaN                   NaN              NaN
# 75%             NaN                   NaN              NaN
# max             NaN                   NaN              NaN

# %%
income_complete.head()
# Out:
#    id   income     sex marital status    age            education  \
# 1   2      75+    male        married  45-54     college graduate
# 2   3      75+  female        married  25-34     college graduate
# 3   4   [0,10)  female         single  14-17          grades 9-11
# 4   5   [0,10)  female         single  14-17          grades 9-11
# 5   6  [50,75)    male        married  55-64  college (1-3 years)
#
#                 occupation years in bay area dual incomes number in household  \
# 1                homemaker               >10           no                   5
# 2  professional/managerial               >10          yes                   3
# 3                  student               >10  not married                   4
# 4                  student               4-6  not married                   4
# 5                  retired               >10           no                   2
#
#   number of children        householder status type of home  \
# 1                  2                       own        house
# 2                  1                      rent    apartment
# 3                  2  live with parents/family        house
# 4                  2  live with parents/family        house
# 5                  0                       own        house
#
#   ethnic classification language in home
# 1                 white          english
# 2                 white          english
# 3                 white          english
# 4                 white          english
# 5                 white          english

# %%
# Total number of transactions and ítems
for item in income_complete:
    print(f"Total items {item}: {income_complete[item].nunique()}")
# Out:
# Total items id: 6876
# Total items income: 9
# Total items sex: 2
# Total items marital status: 5
# Total items age: 7
# Total items education: 6
# Total items occupation: 9
# Total items years in bay area: 5
# Total items dual incomes: 3
# Total items number in household: 9
# Total items number of children: 10
# Total items householder status: 3
# Total items type of home: 5
# Total items ethnic classification: 8
# Total items language in home: 3

# %%
income_complete.groupby('id')['income'].apply(list)
# Out:
# id
# 2           [75+]
# 3           [75+]
# 4        [[0,10)]
# 5        [[0,10)]
# 6       [[50,75)]
#           ...
# 8989     [[0,10)]
# 8990    [[10,15)]
# 8991     [[0,10)]
# 8992    [[20,25)]
# 8993    [[30,40)]
# Name: income, Length: 6876, dtype: object

# %%
encoder = TransactionEncoder()
transaccitions = encoder.fit(income_complete).transform(income_complete)

# %%
transaccitions_df = pd.DataFrame(transaccitions, columns=encoder.columns_)
transaccitions_df
# Out:
#                  a      b      c      d      e      f      g      h      i  \
# 0     False  False  False   True  False   True  False  False  False   True
# 1     False  False  False  False  False   True  False  False  False  False
# 2      True   True  False  False  False  False  False  False  False   True
# 3     False   True  False  False  False   True  False   True  False  False
# 4     False   True  False   True   True   True  False  False  False   True
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6871  False  False  False  False  False  False  False  False  False  False
# 6872  False  False  False  False  False  False  False  False  False  False
# 6873  False  False  False  False  False  False  False  False  False  False
# 6874  False  False  False  False  False  False  False  False  False  False
# 6875  False  False  False  False  False  False  False  False  False  False
#
#       ...      m      n      o      p      r      s      t      u      x  \
# 0     ...   True   True   True  False  False  False  False  False  False
# 1     ...  False  False  False  False  False   True  False  False   True
# 2     ...   True  False  False  False   True   True   True   True  False
# 3     ...  False  False  False  False  False  False  False  False  False
# 4     ...  False   True   True  False  False  False   True   True  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6871  ...  False  False  False  False  False  False  False  False  False
# 6872  ...  False  False  False  False  False  False  False  False  False
# 6873  ...  False  False  False  False  False  False  False  False  False
# 6874  ...  False  False  False  False  False  False  False  False  False
# 6875  ...  False  False  False  False  False  False  False  False  False
#
#           y
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 6871  False
# 6872  False
# 6873  False
# 6874  False
# 6875  False
#
# [6876 rows x 21 columns]
